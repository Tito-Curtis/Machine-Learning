# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
import pandas as pd

# %%
x= np.arange(0,9)

# %%
y= 2*x

# %%
y
# Out:
# array([ 0,  2,  4,  6,  8, 10, 12, 14, 16])

# %%
plt.plot(x,y)
plt.title('tito plot')
plt.xlabel('Volumes of shapes')
plt.xlim(0,8)
plt.ylim(0,16)
plt.ylabel('Sizes');

# %%
fig=plt.figure()
axes=fig.add_axes([0,0,0.5,0.5])
axes.plot(x,y)

# %%
fig

# %%
np.linspace(0,17,11)
# Out:
# array([ 0. ,  1.7,  3.4,  5.1,  6.8,  8.5, 10.2, 11.9, 13.6, 15.3, 17. ])

# %%
fig,axes =plt.subplots(figsize=(5,5),nrows=2,ncols=2)
axes[0][1].plot(x,y)
plt.tight_layout()
plt.subplot

# %%
type(axes)
# Out:
# numpy.ndarray

# %%
x=np.linspace(0,11,10)
x
# Out:
# array([ 0.        ,  1.22222222,  2.44444444,  3.66666667,  4.88888889,
#         6.11111111,  7.33333333,  8.55555556,  9.77777778, 11.        ])

# %%
fig,ax=plt.subplots()
ax.plot(x,x,label='x against x')
ax.plot(x,x**2,label='x against x**2')
ax.legend()
