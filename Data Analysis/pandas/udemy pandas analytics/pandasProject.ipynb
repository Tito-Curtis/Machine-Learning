# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('hotel_bookings.csv')

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.isna()
# Out:
#         hotel  is_canceled  lead_time  arrival_date_year  arrival_date_month  \
# 0       False        False      False              False               False
# 1       False        False      False              False               False
# 2       False        False      False              False               False
# 3       False        False      False              False               False
# 4       False        False      False              False               False
# ...       ...          ...        ...                ...                 ...
# 119385  False        False      False              False               False
# 119386  False        False      False              False               False
# 119387  False        False      False              False               False
# 119388  False        False      False              False               False
# 119389  False        False      False              False               False
#
# ...

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %% [markdown]
# ## how many rows are there

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
len(df)
# Out:
# 119390

# %%
df=df.drop('company',axis=1)

# %%
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %% [markdown]
# ## what are the top 5 most common country code in the dataset

# %%
df['country'].value_counts()[0:5]
# Out:
# PRT    48590
# GBR    12129
# FRA    10415
# ESP     8568
# DEU     7287
# Name: country, dtype: int64

# %%
round((df['stays_in_weekend_nights'] + df['stays_in_week_nights']).mean(),2)
# Out:
# 3.43

# %%
df.head(3)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 0                        0                     0       2  ...
# 1                        0                     0       2  ...
# 2                        0                     1       1  ...
#
#    booking_changes  deposit_type agent days_in_waiting_list customer_type  \
# 0                3    No Deposit   NaN                    0     Transient
# ...

# %%
df[df["total_of_special_requests"] == 5]['hotel']
# Out:
# 7860      Resort Hotel
# 11125     Resort Hotel
# 14596     Resort Hotel
# 14921     Resort Hotel
# 14922     Resort Hotel
# 24630     Resort Hotel
# 27288     Resort Hotel
# 27477     Resort Hotel
# 29906     Resort Hotel
# 29949     Resort Hotel
# 32267     Resort Hotel
# 39027     Resort Hotel
# 39129     Resort Hotel
# 39525     Resort Hotel
# 70114       City Hotel
# 78819       City Hotel
# 78820       City Hotel
# 78822       City Hotel
# 97072       City Hotel
# 97099       City Hotel
# 97261       City Hotel
# 98410       City Hotel
# 98674       City Hotel
# 99887       City Hotel
# 99888       City Hotel
# 101569      City Hotel
# 102061      City Hotel
# 109511      City Hotel
# 109590      City Hotel
# 110082      City Hotel
# 110083      City Hotel
# 111909      City Hotel
# 111911      City Hotel
# 113915      City Hotel
# 114770      City Hotel
# 114909      City Hotel
# 116455      City Hotel
# 116457      City Hotel
# 118817      City Hotel
# 119161      City Hotel
# ...

# %%
round((df['is_repeated_guest']==1).sum()/len(df['is_repeated_guest'])*100,2)
# Out:
# 3.19

# %%
df['babies']= df['babies'].astype(int)

# %%
df['children']= df['children'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 df['children']= df['children'].astype(int)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py:448, in BaseBlockManager.astype(self, dtype, copy, errors)
#     447 def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# ...

# %%
df['total_kids']=df['babies'] + df['children']

# %%
df.sort_values('total_kids',ascending=False)
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 328     Resort Hotel            1         55               2015
# 46619     City Hotel            0         37               2016
# 78656     City Hotel            0         11               2015
# 19718   Resort Hotel            0          0               2016
# 107837    City Hotel            0         13               2017
# ...              ...          ...        ...                ...
# 119389    City Hotel            0        205               2017
# 40600     City Hotel            1          2               2015
# 40667     City Hotel            1          1               2015
# 40679     City Hotel            1          1               2015
# 41160     City Hotel            1          8               2015
#
#        arrival_date_month  arrival_date_week_number  \
# 328                  July                        29
# 46619             January                         3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int32
# ...

# %%
df['arrival_date_month'].unique()
# Out:
# array(['July', 'August', 'September', 'October', 'November', 'December',
#        'January', 'February', 'March', 'April', 'May', 'June'],
#       dtype=object)

# %%
df['arrival_date_month'].apply(df['arrival_date_day_of_month'].apply(lambda x:x in range(1,17)))
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 df['arrival_date_month'].apply(df['arrival_date_day_of_month'].apply(lambda x:x in range(1,17)))
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\anaconda3\lib\site-packages\pandas\core\apply.py:1116, in SeriesApply.apply(self)
#    1114 # dispatch to agg
#    1115 if is_list_like(self.f):
# -> 1116     return self.apply_multiple()
# ...

# %%
df['arrival_date_day_of_month']
# Out:
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
#           ..
# 119385    30
# 119386    31
# 119387    31
# 119388    31
# 119389    29
# Name: arrival_date_day_of_month, Length: 119390, dtype: int64
